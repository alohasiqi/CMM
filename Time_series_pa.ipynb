# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 117

# %%
import os
os.getcwd()

# %%
summary = pd.read_csv("summary.csv")
summary.head()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/siqisun/Downloads/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-32-858742ae9156>", line 1, in <module>
#     summary = pd.read_csv("summary.csv")
#   File "/Users/siqisun/Downloads/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 686, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/Users/siqisun/Downloads/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py", line 452, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
# ...

# %%
pa_time = summary[["pharmacy_claim_approved", "date_val", "calendar_year", "calendar_month"]]
pa_time["date_val"] = pd.to_datetime(pa_time["date_val"]) 
pa_time.index = pa_time["date_val"]
pa_time.head()
# Out:
# <ipython-input-24-d13f29aa9a0a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pa_time["date_val"] = pd.to_datetime(pa_time["date_val"])
#             pharmacy_claim_approved   date_val  calendar_year  calendar_month
# date_val
# 2017-01-01                        0 2017-01-01           2017               1
# 2017-01-01                        1 2017-01-01           2017               1
# 2017-01-01                        0 2017-01-01           2017               1
# 2017-01-01                        1 2017-01-01           2017               1
# 2017-01-01                        1 2017-01-01           2017               1

# %%
pa_time["calendar_year"].value_counts()
# Out:
# 2019    494999
# 2018    455917
# 2017    384660
# Name: calendar_year, dtype: int64

# %%
def date_PA_approved(df, year):
    PA_approval_rates = []
    for i in range(1, 13):
        PA_requests = len(df[(df['calendar_month']==i) &(df['calendar_year']==year)])
        PA_approved = len(df[(df['calendar_month']==i)&(df['pharmacy_claim_approved']==1)&(df['calendar_year']==year)])
        
        PA_approval_rate = (PA_approved/PA_requests)*100
        PA_approval_rates.append(PA_approval_rate)
    return PA_approval_rates
approval_rate_2019 = date_PA_approved(dim_date_claim_pa, 2019)
approval_rate_2018 = date_PA_approved(dim_date_claim_pa, 2018)
approval_rate_2017 = date_PA_approved(dim_date_claim_pa, 2017)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/siqisun/Downloads/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-31-55b17c250dd3>", line 10, in <module>
#     approval_rate_2019 = date_PA_approved(dim_date_claim_pa, 2019)
# NameError: name 'dim_date_claim_pa' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/siqisun/Downloads/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
# ...

# %%
        pa_approve = sum(records)
        pa_time["pa_rate"]
years = pa_time["calendar_year"].unique()

# %%
# Draw Plot
plt.figure(figsize=(16,12), dpi= 80)
for i, y in enumerate(years):
    if i > 0:        
        plt.plot('month', 'value', data=pa_time.loc[pa_time.year==y, :], color=mycolors[i], label=y)
        plt.text(pa_time.loc[pa_time.year==y, :].shape[0]-.9, pa_time.loc[pa_time.year==y, 'value'][-1:].values[0], y, fontsize=12, color=mycolors[i])
